# %% [markdown]
# # Data Processing
# * Intent Dataset을 corpus로 활용하여 Word2vec학습을 위한 데이터 처리

# %%
import os
import sys
import json
import torch
import pandas as pd
import numpy as np

from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

from gensim.models import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (1.10.1)
# Requirement already satisfied: typing-extensions in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from torch) (4.0.1)
# WARNING: You are using pip version 20.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install --upgrade gensim==3.4.0
# Out:
# Requirement already up-to-date: gensim==3.4.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (3.4.0)
# Requirement already satisfied, skipping upgrade: smart-open>=1.2.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from gensim==3.4.0) (5.2.1)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from gensim==3.4.0) (1.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from gensim==3.4.0) (1.21.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\lib\site-packages (from gensim==3.4.0) (1.7.3)
# WARNING: You are using pip version 20.2.1; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\it강남-e강의장(강사용)\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
class Preprocessing:
    
    def __init__(self, max_len = 20):
        self.max_len = max_len
        self.PAD = 0
    
    def pad_idx_sequencing(self, q_vec):
        q_len = len(q_vec)
        diff_len = q_len - self.max_len
        if(diff_len>0):
            q_vec = q_vec[:self.max_len]
            q_len = self.max_len
        else:
            pad_vac = [0] * abs(diff_len)
            q_vec += pad_vac

        return q_vec
    
class MakeDataset:
    
    def __init__(self):
        
        self.intent_data_dir = "./data/dataset/intent_data.csv"
        self.prep = Preprocessing()
    
    def tokenize(self, sentence):
        ''' 띄어쓰기 단위로 tokenize 적용'''
        return sentence.split()
    
    def tokenize_dataset(self, dataset):
        ''' Dataset에 tokenize 적용'''
        token_dataset = []
        for data in dataset:
            token_dataset.append(self.tokenize(data))
        return token_dataset
    
    def make_embed_dataset(self, ood = False):
        embed_dataset = pd.read_csv(self.intent_data_dir)
        embed_dataset = embed_dataset["question"].to_list()
        embed_dataset = self.tokenize_dataset(embed_dataset)

        return embed_dataset

# %%
dataset = MakeDataset()
embed_dataset = dataset.make_embed_dataset()

# %%
embed_dataset
# Out:
# [['야', '먼지', '알려주겠니'],
#  ['아니', '먼지', '정보', '알려주세요'],
#  ['그', '때', '미세먼지', '어떨까'],
#  ['그', '때', '먼지', '좋으려나'],
#  ['미세먼지', '어떨', '것', '같은데'],
#  ['그러면', '미세먼지', '어때'],
#  ['미세먼지', '말해줄래'],
#  ['먼지', '미세먼지'],
#  ['참', '먼지', '많이', '꼈나'],
#  ['참', '먼지', '어떠냐'],
#  ['야', '미세먼지', '어때'],
#  ['토요일', '먼지', '알려줘'],
#  ['헐', '먼지', '어떠려나'],
#  ['전주', '미세먼지', '어떤지', '말해줘'],
#  ['미세먼지', '궁금해서', '물어봤어'],
#  ['아', '그러면', '먼지', '알려주세요'],
#  ['아', '맞다', '먼지', '어떠려나'],
#  ['저기', '현재', '먼지', '어떠려나'],
#  ['토요일', '먼지', '알려주겠니'],
#  ['먼지', '궁금해'],
#  ['지금', '먼지', '어떤데'],
#  ['저기', '미세먼지', '어떨까'],
#  ['먼지', '완전', '문젠데'],
#  ['세종', '먼지', '한', '번', '알려줘'],
#  ['모레', '먼지', '궁금해'],
#  ['먼지', '궁금해요'],
#  ['미세먼지', '어떨까'],
#  ['지금', '미세먼지', '어떨까', '심해지네'],
#  ['현재', '미세먼지', '어떨까'],
#  ['공기', '미세먼지', '좀', '알려줄래'],
#  ['미세먼지', '먼지'],
#  ['미세먼지', '좀', '먼지'],
#  ['월요일', '근데', '먼지', '어떠려나'],
#  ['미세먼지', '없니', '현재'],
#  ['지금', '미세먼지', '없니', '현재'],
#  ['공기', '미세먼지', '현재'],
#  ['공기상태', '알려줘'],
#  ['아', '먼지', '심하네'],
#  ['어떤데', '먼지'],
#  ['먼지', '알려줬으면', '졸겠어'],
#  ['미세먼지', '없나', '하'],
#  ['지금', '먼지', '많네'],
#  ['월요일', '여행갈건데', '먼지', '알려줘'],
#  ['먼지', '궁금하네'],
#  ['토요일', '먼지', '심하니'],
#  ['월요일', '미세먼지', '심할까'],
#  ['먼지', '많이', '심하려나'],
#  ['알려주세요', '먼지'],
#  ['먼지', '꼈나'],
#  ['먼지', '끼었나'],
#  ['현재', '지금', '먼지', '많니'],
#  ['먼지', '알려주세요', '궁금해요'],
#  ['미세먼지', '혹시라도', '심할까'],
#  ['먼지', '안', '심해야', '하는데'],
#  ['나한테', '공기상태', '알려줘'],
#  ['나', '궁금한데', '미세먼지', '알려줘'],
#  ['여행', '갈건데', '미세먼지', '어때'],
#  ['나', '서울', '여행', '가는데', '미세먼지', '알려줘'],
#  ['월요일', '먼지', '깨끗하니'],
#  ['서울', '다음', '주', '먼지', '알려줄래요'],
#  ['부안', '먼지', '어떻게', '돼'],
#  ['토요일', '서천', '미세먼지', '어떨까', '좀', '알려줄수', '있니'],
#  ['월요일', '공기상태', '알려줄수', '있어'],
#  ['이번', '주', '가로수길', '미세먼지', '알려줄래'],
#  ['구암', '다음', '주', '미세먼지', '알려줘'],
#  ['이번', '주', '영등포', '먼지', '말해줘'],
#  ['구로', '다음', '주', '미세먼지', '알려줄래'],
#  ['일산', '미세먼지', '어떨까', '어떻게', '돼요'],
#  ['토요일', '안암', '미세먼지', '어떨까', '좀', '알려줄수', '있니'],
#  ['월요일', '미세먼지', '알려줄', '수', '있어'],
#  ['이번', '주', '홍대', '미세먼지', '알려줄래'],
#  ['남구', '다음', '주', '미세먼지', '알려줘'],
#  ['이번', '주', '보령', '먼지', '줘'],
#  ['공기', '미세먼지'],
#  ['공기', '먼지', '심하니'],
#  ['현재', '미세먼지', '많이', '없니'],
#  ['먼지', '많이', '없니'],
#  ['공기', '많이', '깨끗하지'],
#  ['여행', '가는데', '먼지', '많이', '심할까'],
#  ['알려줘', '공기상태', '미세먼지', '궁금해'],
#  ['월요일', '마스크', '챙길까'],
#  ['마스크', '써야하나'],
#  ['이번', '주', '먼지', '많이', '없니'],
#  ['월요일', '먼지', '심하겠지'],
#  ['헉', '혹시', '먼지', '심할까'],
#  ['먼지', '심하니'],
#  ['월요일', '미세먼지', '어떨까', '나쁠까'],
#  ['먼지', '심하겠지', '글쎄'],
#  ['먼지', '심해지려나'],
#  ['토요일', '먼지', '심하니'],
#  ['미세먼지', '알려줘'],
#  ['화요일', '미세먼지', '어떨까', '나쁠까'],
#  ['공기', '미세먼지', '나쁠까'],
#  ['혹시', '화요일', '먼지', '심하니', '마스크', '챙길까'],
#  ['마스크', '필요하니'],
#  ['화요일', '마스크', '필요할까'],
#  ['마스크', '챙겨야하나', '모르겠네'],
#  ['밀양', '먼지', '심하면', '안되는데'],
#  ['공기', '미세먼지', '그', '때'],
#  ['혹시', '먼지', '심하니'],
#  ['그', '때', '혹시', '미세먼지', '어떨까', '나쁠까'],
#  ['나', '화요일', '여행가는데', '미세먼지', '알려줘'],
#  ['그럼', '미세먼지', '혹시', '심하려나', '하'],
#  ['하늘', '심하니'],
#  ['미세먼지', '없으려'],
#  ['먼지', '꼈니'],
#  ['강남', '미세먼지', '심할까'],
#  ['공기', '미세먼지', '심해질까'],
#  ['그', '때', '하늘', '어떠려나'],
#  ['하늘', '미세먼지', '많이', '심하니', '그', '날'],
#  ['먼지', '어떨', '것', '같아'],
#  ['이번', '주', '먼지', '깨끗하니'],
#  ['많이', '먼지', '심하면', '안될텐데'],
#  ['다음', '주', '미세먼지', '알려줘'],
#  ['화요일', '먼지', '심할까'],
#  ['화요일', '혹시', '서대문구', '먼지', '없으려나'],
#  ['토요일', '미세먼지', '심하니'],
#  ['군산', '미세먼지', '어떨까', '좋으려나'],
#  ['공기', '미세먼지', '나쁠까', '정말'],
#  ['먼지', '없을까'],
#  ['화요일', '미세먼지', '심하겠지', '글쎄'],
#  ['화요일', '미세먼지', '심하면', '안되는데'],
#  ['혹시', '미세먼지', '안심하겠지'],
#  ['의정부', '미세먼지', '없을까'],
#  ['수요일', '마스크', '필요해'],
#  ['마스크', '쓸까'],
#  ['수요일', '마스크', '챙길까', '말까'],
#  ['먼지', '궁금한데', '알려주겠니'],
#  ['혹시', '미세먼지', '알려줘'],
#  ['수요일', '동두천', '먼지', '궁금해요'],
#  ['수요일', '먼지', '궁금해'],
#  ['먼지', '많이', '심한가'],
#  ['서울', '미세먼지', '알려주겠니'],
#  ['부산', '먼지', '정보', '알려주세요'],
#  ['혹시', '그', '때', '대구', '미세먼지', '어떨까'],
#  ['그', '때', '대전', '먼지', '좋겠지'],
#  ['먼지', '어떨', '것', '같은데'],
#  ['울산', '미세먼지', '어떨까요'],
#  ['송파구', '황사', '미세먼지'],
#  ['덕진구', '현재', '먼지', '말해주겠니'],
#  ['청주', '황사', '미세먼지'],
#  ['토요일', '전주', '황사', '알려줘'],
#  ['먼지', '어떠려나'],
#  ['그럼', '구리', '황사', '미세먼지'],
#  ['전주', '황사', '어떤지', '좀', '말해줘'],
#  ['창원', '황사', '궁금해서', '물어봤어요'],
#  ['경기도', '황사', '알려주세요'],
#  ['공기', '어떠려나'],
#  ['현재', '먼지', '어떠려나'],
#  ['현재공기', '어떠려나'],
#  ['토요일', '황사', '알려주겠니'],
#  ['먼지', '궁금해'],
#  ['현재', '황사', '어떤데'],
#  ['저기', '북구', '황사', '미세먼지'],
#  ['현재', '인천', '황사', '완전', '문젠데'],
#  ['완주', '모레', '동대구', '황사', '궁금해'],
#  ['먼지', '궁금해요'],
#  ['완산구', '현재', '미세먼지', '어떨까', '좋니'],
#  ['지금', '황사', '미세먼지'],
#  ['송파구', '미세먼지', '어떨까', '좀', '알려줄래'],
#  ['궁금해', '부천', '미세먼지'],
#  ['미세먼지', '좀', '안산', '먼지'],
#  ['수요일', '근데', '원주', '황사', '어떠려나'],
#  ['울산', '지금', '미세먼지', '없니'],
#  ['하늘', '미세먼지', '없니', '지금'],
#  ['광주', '공기상태', '알려줘'],
#  ['어떤데', '먼지'],
#  ['먼지', '알려줬으면', '졸겠어'],
#  ['평창', '황사', '알려줘'],
#  ['토요일', '미세먼지', '없나'],
#  ['모레', '여행갈건데', '먼지', '알려줘'],
#  ['먼지', '궁금하네'],
#  ['토요일', '먼지', '심하니'],
#  ['수요일', '오존', '미세먼지'],
#  ['알려주세요', '춘천', '먼지'],
#  ['광주', '북구', '먼지', '어떠려나'],
#  ['먼지', '알려주세요', '궁금해요'],
#  ['그', '날', '먼지', '많이', '심하겠지'],
#  ['맑으려나', '수요일'],
#  ['먼지', '궁금해서'],
#  ['먼지', '안', '심해야', '하는데'],
#  ['무주', '공기상태', '알려줘'],
#  ['수요일', '먼지', '깨끗하니'],
#  ['미세먼지', '심할까'],
#  ['하늘', '미세먼지', '어떨까'],
#  ['하늘', '먼지', '심하니'],
#  ['지금', '남원', '오존', '많이', '없니'],
#  ['지금', '경부', '지방', '많이', '오존', '심할까'],
#  ['먼지', '많이', '심할까'],
#  ['알려줘', '은평구', '먼지'],
#  ['노원구', '먼지', '궁금하네'],
#  ['수요일', '마스크', '챙길까'],
#  ['진짜', '영덕', '미세먼지', '어떨까', '하'],
#  ['임실', '수요일', '혹시', '마스크', '써야하나'],
#  ['이번', '주', '먼지', '많이', '없니'],
#  ['수요일', '먼지', '심하겠지'],
#  ['홍대', '혹시', '오존', '심할까'],
#  ['서울', '먼지', '심하니'],
#  ['먼지', '껴서', '흐린가'],
#  ['먼지', '심하진', '않겠지'],
#  ['너무', '먼지', '심하지', '않으려나'],
#  ['마스크', '글쎄', '챙겨야겠지'],
#  ['해운대', '목요일', '먼지', '없을까'],
#  ['오수', '먼지', '심하겠지', '글쎄'],
#  ['그', '떄', '오존', '심할까'],
#  ['먼지', '심해지려나'],
#  ['오존', '알려줘'],
#  ['서귀포', '목요일', '미세먼지', '어떨까', '나쁠까'],
#  ['먼지', '심하면', '안되는데'],
#  ['제주', '많이', '미세먼지', '어떨까', '나쁠까'],
#  ['먼지', '너무', '많이', '없나'],
#  ['혹시', '목요일', '먼지', '심하니', '마스크', '챙길까'],
#  ['여수', '지금', '마스크', '필요하니'],
#  ['순천', '목요일', '마스크', '필요할까'],
#  ['마스크', '챙겨야하나', '모르겠네'],
#  ['먼지', '심하면', '안되는데'],
#  ['건대', '입구', '미세먼지', '어떨까', '그', '때'],
#  ['혹시', '먼지', '심하니'],
#  ['그', '때', '혹시', '미세먼지', '어떨까', '나쁠까'],
#  ['나', '목요일', '여행가는데', '먼지', '알려줘'],
#  ['그럼', '미세먼지', '혹시', '심하려나'],
#  ['하늘', '심하니'],
#  ['지금', '먼지', '없나'],
#  ['오존', '없으려나'],
#  ['이번', '주', '심할까'],
#  ['공기', '미세먼지', '심해질까'],
#  ['그', '때', '하늘', '어떠려나'],
#  ['하늘', '오존', '많이', '심하니', '그', '날'],
#  ['먼지', '어떨', '것', '같아'],
#  ['이번', '주', '먼지', '깨끗하니'],
#  ['많이', '먼지', '심하면', '안될텐데'],
#  ['다음', '주', '미세먼지', '알려줘'],
#  ['목요일', '먼지', '심할까'],
#  ['먼지', '많이', '심하니'],
#  ['영월', '먼지', '많이', '심한가'],
#  ['금요일', '혹시', '먼지', '없으려나'],
#  ['일요일', '오존', '심하니'],
#  ['공기', '미세먼지', '좋으려나'],
#  ['1월', '1일', '먼지', '심한가요'],
#  ['2월', '12일', '오존', '심하려나'],
#  ['3월', '3일', '오존', '심한가'],
#  ['4월', '14일', '먼지', '심한가요'],
#  ['5월', '5일', '추워서', '오존', '심한가'],
#  ['8일', '호성동', '먼지', '알려줘'],
#  ['6월', '22일', '먼지', '심한가요'],
#  ['12월', '11일', '미세먼지', '어떠려나'],
#  ['3월', '2O일', '먼지', '와'],
#  ['7월', '4일', '오존', '와'],
#  ['3월', '17일', '전주', '하늘', '먼지', '심하니'],
#  ['4월', '12일', '먼지', '심해서', '안', '되겠다'],
#  ['이번', '주', '토요일', '먼지', '심하니'],
#  ['2월', '1O일', '먼지', '심하니'],
#  ['경주', '이번', '주', '드디어', '맑아'],
#  ['4월', '11일', '오존', '심한가요'],
#  ['2월', '2O일', '먼지', '와'],
#  ['8월', '4일', '오존', '와'],
#  ['1O월', '16일', '먼지', '심하니'],
#  ['이번', '주', '수요일', '먼지', '심하니'],
#  ['11월', '6일', '청원', '먼지', '심하니'],
#  ['이천', '이번', '주', '심하려나', '하늘'],
#  ['먼지', '없을까'],
#  ['금요일', '오산', '오존', '심하겠지', '글쎄'],
#  ['금요일', '오존', '심하니'],
#  ['혹시', '오존', '안심하겠지'],
#  ['그', '날', '먼지와서', '힘들겠지'],
#  ['오존', '없을까'],
#  ['약속', '잡았는데', '먼지', '심하네'],
#  ['금요일', '진주', '마스크', '필요해'],
#  ['마스크', '쓸까', '말해줘'],
#  ['울릉도', '금요일', '마스크', '챙길까', '말까'],
#  ['먼지', '궁금한데', '알려주겠니'],
#  ['혹시', '먼지', '알려줘'],
#  ['인천', '금요일', '먼지', '궁금해요'],
#  ['내일모레', '먼지', '궁금해'],
#  ['내일', '먼지', '깨끗하니'],
#  ['이천', '하늘', '미세먼지', '어떨까'],
#  ['화순', '하늘', '먼지', '심하니'],
#  ['지금', '남원', '오존', '많이', '없니'],
#  ['지금', '경부', '지방', '먼지', '많이', '없니'],
#  ['공기', '깨끗하니'],
#  ['노원구', '먼지', '궁금하네'],
#  ['이따가', '마스크', '챙길까'],
#  ['이태원', '마스크', '써야하나'],
#  ['이번', '주', '먼지', '많이', '없니'],
#  ['내일', '먼지', '심하겠지'],
#  ['일요일', '먼지', '알려주세요'],
#  ['혹시', '이따', '미세먼지', '어떨까', '좀', '알려줄래요'],
#  ['내일', '먼지', '알려주세요'],
#  ['저번', '주', '먼지', '말해주세요'],
#  ['이번', '주', '먼지', '없니'],
#  ['먼지', '어떠냐'],
#  ['지금', '어떤데', '먼지'],
#  ['다음', '주', '광명', '먼지', '알려주세요'],
#  ['지금', '평택', '먼지', '알려주세요'],
#  ['이번', '주', '광주', '먼지', '말해주라'],
#  ['내일', '부산', '먼지'],
#  ['내일', '대구', '먼지', '말해'],
#  ['이따', '대전', '먼지', '말해줘'],
#  ['일요일', '먼지', '뭐야'],
#  ['내일', '부산', '먼지', '말해주라'],
#  ['부산', '먼지'],
#  ['경북', '내일', '미세먼지', '어떨까'],
#  ['익산', '먼지', '어떨', '것', '같은지', '말해줘'],
#  ['2월', '2O일', '먼지', '알려주겠니'],
#  ['1월', '3O일', '먼지', '정보', '알려주세요'],
#  ['6월', '그', '때', '미세먼지', '어떨까'],
#  ['8월', '그', '때', '먼지', '좋으려나'],
#  ['호성동', '먼지', '어떨', '것', '같은데'],
#  ['덕진동', '미세먼지', '어떨까'],
#  ['송천동', '먼지', '말해줄래'],
#  ['나운동', '먼지', '미세먼지'],
#  ['미룡동', '먼지', '많이', '꼈나'],
#  ['조촌동', '먼지', '어떠냐'],
#  ['금천구', '야', '미세먼지', '어떨까'],
#  ['노원구', '일요일', '먼지', '알려줬으면'],
#  ['5월', '5일', '먼지', '어떠려나'],
#  ['4월', '8일', '음성', '먼지', '어떤지', '말해달라고'],
#  ['1월', '11일', '먼지', '궁금해서', '물어봤는데'],
#  ['2월', '28일', '미세먼지', '어떨까', '좀', '알려주세요'],
#  ['일요일', '수원', '먼지', '어떠려나'],
#  ['고양시', '현재', '먼지', '어떠려나'],
#  ['용인', '일요일', '먼지', '알려주겠니'],
#  ['성남', '먼지', '궁금해'],
#  ['부천', '지금', '먼지', '어떤데'],
#  ['화성', '미세먼지', '어떨까'],
#  ['남양주', '먼지', '완전', '문젠데'],
#  ['세종', '먼지', '한', '번', '알려줘'],
#  ['천안', '모레', '먼지', '궁금해'],
#  ['안산', '먼지', '궁금해요'],
#  ['안양', '미세먼지', '어떨까'],
#  ['김포', '미세먼지', '어떨까'],
#  ['평택', '지금', '미세먼지', '어떨까'],
#  ['파주', '미세먼지', '어떨까', '좀', '알려줄래'],
#  ['미세먼지', '의정부', '먼지'],
#  ['미세먼지', '김포', '먼지'],
#  ['내일', '근데', '구미', '먼지', '어떠려나'],
#  ['양산', '오존', '없니', '지금'],
#  ['원주', '하늘', '오존', '없니', '지금'],
#  ['진주', '미세먼지', '어떨까', '지금'],
#  ['세종', '공기상태', '알려줘'],
#  ['아', '광명', '먼지', '심하네'],
#  ['어떤데', '아산', '먼지'],
#  ['익산', '먼지', '알려줬으면', '졸겠어'],
#  ['춘천', '지금', '오존', '없나'],
#  ['경산', '하늘', '오존', '많네'],
#  ['내일', '군포', '여행갈건데', '오존', '알려줘'],
#  ['하남', '오존', '궁금하네'],
#  ['일요일', '여수', '초미세먼지', '심하니'],
#  ['내일', '경주', '초미세먼지', '심할까'],
#  ['거제도', '초미세먼지', '많이', '심하려나'],
#  ['목포', '알려주세요', '먼지'],
#  ['이천', '초미세먼지', '꼈나'],
#  ['강릉', '초미세먼지', '끼었나'],
#  ['양주', '지금', '하늘', '초미세먼지', '많니'],
#  ['충주', '초미세먼지', '알려주세요', '궁금해요'],
#  ['안성', '맑으려나', '내일'],
#  ['서산', '초미세먼지', '궁금해서'],
#  ['구리', '내일', '초미세먼지', '안', '심해야', '하는데'],
#  ['서귀포', '미세먼지', '알려줘'],
#  ['당진', '내일', '미세먼지', '깨끗하니'],
#  ['안동', '다음', '주', '초미세먼지', '알려줄래요'],
#  ['포천', '먼지', '어떻게', '돼'],
#  ['일요일', '의왕', '미세먼지', '심할까', '좀', '알려줄수', '있니'],
#  ['내일', '초미세먼지', '광양', '알려줄수', '있어'],
#  ['이번', '주', '제천', '초미세먼지', '알려줄래'],
#  ['논산', '다음', '주', '초미세먼지', '알려줘'],
#  ['이번', '주', '칠곡', '초미세먼지', '줘'],
#  ['여주', '다음', '주', '초미세먼지', '알려줄래'],
#  ['정읍', '먼지', '어떻게', '돼요'],
#  ['일요일', '음성군', '미세먼지', '심할까', '좀', '알려줄수', '있니'],
#  ['내일', '양평', '꽃가루', '알려줄수', '있어'],
#  ['이번', '주', '공주', '꽃가루', '알려줄래'],
#  ['완주', '다음', '주', '꽃가루', '알려줘'],
#  ['이번', '주', '상주', '꽃가루', '줘'],
#  ['영천', '내일', '하늘', '미세먼지', '심할까'],
#  ['동두천', '일요일', '꽃가루', '심하니'],
#  ['김제', '지금', '꽃가루', '많이', '없니'],
#  ['무안', '꽃가루', '없니'],
#  ['진천', '꽃가루', '많이', '심하니'],
#  ['예산군', '꽃가루', '알려줘'],
#  ['문경', '내일', '마스크', '챙길까'],
#  ['속초', '모레', '마스크', '써야하나'],
#  ['이번', '주', '삼척', '꽃가루', '많이', '없니'],
#  ['홍천', '내일', '먼지', '심하겠지'],
#  ['해남', '혹시', '미세먼지', '깨끗하니'],
#  ['창녕', '꽃가루', '심하니'],
#  ['내일', '태안', '미세먼지', '심할까', '나쁠까'],
#  ['고흥', '먼지', '심하겠지', '글쎄'],
#  ['화순', '꽃가루', '심해지려나'],
#  ['거창', '일요일', '꽃가루', '심하니'],
#  ['가평', '꽃가루', '알려줘'],
#  ['내일', '고창', '미세먼지', '심할까', '나쁠까'],
#  ['서천', '미세먼지', '심할까', '나쁠까'],
#  ['혹시', '내일', '금산', '먼지', '심하니', '마스크', '챙길까'],
#  ['부안', '일요일', '마스크', '필요하니'],
#  ['내일', '옥천', '마스크', '필요할까'],
#  ['영광', '마스크', '챙겨야하나', '모르겠네'],
#  ['울진', '꽃가루', '심하면', '안되는데'],
#  ['완도', '미세먼지', '심할까', '그', '때'],
#  ['혹시', '담양', '이번', '주', '꽃가루', '심하니'],
#  ['그', '때', '횡성', '혹시', '미세먼지', '심할까', '나쁠까'],
#  ['나', '내일', '계룡', '여행가는데', '꽃가루', '알려줘'],
#  ['아', '미세먼지', '혹시', '심하려나'],
#  ['장성', '하늘', '심하니'],
#  ['청도', '이따가', '꽃가루', '없으려나'],
#  ['괴산', '꽃가루', '꼈니'],
#  ['강남', '하늘', '미세먼지', '심할까'],
#  ['함양', '일요일', '꽃가루', '심하나'],
#  ['그', '때', '하늘', '어떠려나'],
#  ['증평', '하늘', '꽃가루', '많이', '심하니', '그', '날'],
#  ['영월', '꽃가루', '어떨', '것', '같아'],
#  ['이번', '주', '장흥', '미세먼지', '깨끗하니'],
#  ['영덕', '미세먼지', '어때상태', '심하면', '안될텐데'],
#  ['다음', '주', '정선', '미세먼지', '알려줘'],
#  ['내일', '강진', '꽃가루', '심할까'],
#  ['내일', '혹시', '보은', '꽃가루', '없으려나'],
#  ['오늘', '인제', '미세먼지', '심하니'],
#  ['진도', '미세먼지', '심할까', '좋으려나'],
#  ['군산', '미세먼지', '심할까', '미세먼지', '나쁠까', '정말'],
#  ['곡성', '미세먼지', '없을까'],
#  ['내일', '단양', '미세먼지', '심하겠지', '글쎄'],
#  ['내일', '순창', '미세먼지', '심하면', '안되는데'],
#  ['혹시', '의령', '미세먼지', '안', '심하겠지'],
#  ['양양', '의정부', '미세먼지', '없을까'],
#  ['내일', '화천', '마스크', '필요해'],
#  ['청송', '마스크', '쓸까'],
#  ['내일', '구례', '마스크', '챙길까', '말까'],
#  ['무주', '미세먼지', '궁금한데', '알려주겠니'],
#  ['진안', '혹시', '미세먼지', '알려줘'],
#  ['내일모레', '양구', '미세먼지', '궁금해요'],
#  ['내일모레', '군위', '미세먼지', '궁금해'],
#  ['장수', '미세먼지', '많이', '심한가'],
#  ['영양', '미세먼지', '알려주겠니'],
#  ['울릉', '미세먼지', '정보', '알려주세요'],
#  ['혹시', '그', '때', '종로구', '미세먼지', '미세먼지'],
#  ['그', '때', '관악구', '미세먼지', '좋겠지'],
#  ['서초구', '미세먼지', '어떨', '것', '같은데'],
#  ['강동구', '미세먼지', '미세먼지'],
#  ['도봉구', '미세먼지', '미세먼지'],
#  ['중랑구', '현재', '미세먼지', '말해주겠니'],
#  ['광진구', '청주', '미세먼지', '미세먼지'],
#  ['오늘', '용산구', '미세먼지', '알려줘'],
#  ['마포구', '미세먼지', '미세먼지'],
#  ['그럼', '강남', '미세먼지', '미세먼지'],
#  ['강동', '미세먼지', '어떤지', '좀', '말해줘'],
#  ['동작구', '미세먼지', '궁금해서', '물어봤어요'],
#  ['경상도', '미세먼지', '알려주세요'],
#  ['경남', '미세먼지', '어떠려나'],
#  ['전북', '현재', '미세먼지', '어떠려나'],
#  ['전남', '스모크', '어떠려나'],
#  ['오늘', '전북', '스모크', '알려주겠니'],
#  ['영등포', '스모크', '궁금해'],
#  ['현재', '양천구', '스모크', '어떤데'],
#  ['저기', '마포구', '스모크', '미세먼지'],
#  ['현재', '성북구', '스모크', '완전', '문젠데'],
#  ['중랑구', '스모크', '궁금해'],
#  ['용산구', '스모크', '궁금해요'],
#  ['종로구', '현재', '미세먼지', '심할까', '좋니'],
#  ['현재', '스모크', '미세먼지'],
#  ['송파구', '미세먼지', '심할까', '좀', '알려줄래'],
#  ['미세먼지', '마포구', '스모크'],
#  ['제주시', '스모크', '궁금해'],
#  ['합천군', '스모크', '궁금해'],
#  ['오늘', '함안군', '미세먼지', '어때'],
#  ['창녕군', '미세먼지', '심할까'],
#  ['고성군', '스모크', '알려줘'],
#  ['거제시', '스모그', '알려줄래'],
#  ['오늘', '의성군', '스모그', '알려줘'],
#  ['울진군', '미세먼지', '어때'],
#  ['영천시', '스모그', '미세먼지'],
#  ['구미시', '스모그', '미세먼지'],
#  ['봉화군', '미세먼지', '심할까'],
#  ['태안군', '미세먼지', '알려줘'],
#  ['미세먼지', '스모그', '논산시'],
#  ['계룡시', '스모그', '미세먼지'],
#  ['오늘', '청주시', '흥덕구', '스모그', '알려줘'],
#  ['오늘', '진천군', '스모그', '미세먼지'],
#  ['증평군', '미세먼지', '심할까'],
#  ['제천시', '미세먼지', '알려줘'],
#  ['화천군', '미세먼지', '어때'],
#  ['홍천군', '미세먼지', '알려줘'],
#  ['원주시', '미세먼지', '물어볼게'],
#  ['영월군', '미세먼지', '알려줄래'],
#  ['서초구', '미세먼지', '어때'],
#  ['속초시', '스모그', '알려줘'],
#  ['강릉시', '스모그', '궁금해'],
#  ['울산', '북구', '스모그', '미세먼지'],
#  ['계양구', '스모그', '알려줘'],
#  ['오늘', '부평구', '스모그', '미세먼지'],
#  ['인천', '서구', '미세먼지', '궁금해'],
#  ['연수구', '미세먼지', '알려줘'],
#  ['미추홀구', '미세먼지', '궁금해요'],
#  ['사하구', '미세먼지', '어때'],
#  ['해운대구', '미세먼지', '어떠려나'],
#  ['오늘', '북구', '스모그', '미세먼지'],
#  ['오늘', '동래구', '미세먼지', '알려줘'],
#  ['금정구', '스모그', '미세먼지'],
#  ['부산', '강서구', '미세먼지', '알려줘'],
#  ['오늘', '안성시', '미세먼지', '알려줄래'],
#  ['수원시', '팔달구', '미세먼지', '알려줘'],
#  ['동두천시', '미세먼지', '알려줘'],
#  ['양주시', '스모그', '궁금해'],
#  ['양주시', '미세먼지', '알려주세요'],
#  ['안성시', '미세먼지', '어때'],
#  ['합정동', '미세먼지', '알려줘'],
#  ['망원동', '미세먼지', '알려줘'],
#  ['연천군', '미세먼지', '심할까'],
#  ['이천시', '스모그', '미세먼지'],
#  ['하남시', '스모그', '궁금해요'],
#  ['화성시', '스모그', '알려줘'],
#  ['군포시', '미세먼지', '알려주세요'],
#  ['구리시', '미세먼지', '알려줘'],
#  ['광명시', '미세먼지', '궁금합니다'],
#  ['고양시', '덕양구', '스모그', '알려줘'],
#  ['가평군', '미세먼지', '궁금해'],
#  ['구로구', '스모그', '알려줘'],
#  ['은평구', '스모그', '알려줘'],
#  ['종로구', '스모그', '궁금해'],
#  ['오늘', '미세먼지', '익산시', '스모그'],
#  ['인천', '동구', '스모그', '궁금해'],
#  ['웅진군', '미세먼지', '궁금해'],
#  ['부산진구', '미세먼지', '알려줘'],
#  ['동래구', '스모그', '알려줄래'],
#  ['음성군', '스모그', '알려주세요'],
#  ['고양시', '일산서구', '스모그', '알려줄래'],
#  ['의정부시', '미세먼지', '궁금해'],
#  ['용인시', '수지구', '미세먼지', '어때'],
#  ['오산시', '미세먼지', '알려줘'],
#  ['성남시', '분당구', '미세먼지', '알려주세요'],
#  ['삼척시', '미세먼지', '궁금해요'],
#  ['오늘', '원주시', '스모그', '미세먼지'],
#  ['한강', '가는데', '근처', '미세먼지', '알려줘'],
#  ['광화문', '미세먼지', '알려줘'],
#  ['통영시', '스모그', '미세먼지'],
#  ['광주시', '스모그', '알려줘'],
#  ['사천시', '스모그', '미세먼지'],
#  ['안산시', '황사', '알려줄래'],
#  ['여주시', '미세먼지는'],
#  ['파주시', '황사', '알려줘'],
#  ['남구', '미세먼지', '어때'],
#  ['수영구', '미세먼지', '알려줘'],
#  ['동래구', '황사', '궁금해'],
#  ['태백시', '미세먼지', '어때'],
#  ['설악산', '가는데', '근처', '미세먼지', '어떠니'],
#  ['한라산', '가는데', '근처', '미세먼지', '어때'],
#  ['성미산', '가는데', '근처', '황사', '미세먼지'],
#  ['하늘공원', '가는데', '근처', '황사', '궁금해'],
#  ['시청', '가는데', '근처', '황사', '궁금해'],
#  ['오늘', '경리단길', '가는데', '황사', '미세먼지'],
#  ['오늘', '망리단길', '가는데', '미세먼지', '어떠니'],
#  ['오늘', '을왕리', '가는데', '근처', '미세먼지', '어때'],
#  ['임자도', '황사', '미세먼지'],
#  ['교동도', '황사', '알려줘'],
#  ['자은도', '가려는데', '오늘', '황사', '알려줄래'],
#  ['압해도', '가는데', '황사', '궁금해요'],
#  ['대연평도', '가려는데', '오늘', '황사', '미세먼지'],
#  ['생일도', '황사', '알려주세요'],
#  ['원산도', '오늘', '황사', '알려줘'],
#  ['안도', '오늘', '황사', '미세먼지'],
#  ['오늘', '죽도', '미세먼지', '어때'],
#  ['외도', '가는데', '미세먼지', '어때'],
#  ['가덕도', '오늘', '미세먼지', '알려줘'],
#  ['석모도', '황사', '궁금해요'],
#  ['신의도', '오늘', '황사', '알려줄래'],
#  ['사랑도', '오늘', '미세먼지', '알려줄래'],
#  ['팔금도', '오늘', '미세먼지', '궁금해'],
#  ['외나로도', '황사', '알려줘'],
#  ['우도', '황사', '알려줘'],
#  ['선유도', '오늘', '미세먼지', '어때'],
#  ['영흥도', '오늘', '미세먼지', '알려줄래'],
#  ['중도', '오늘', '황사', '알려줘'],
#  ['도초도', '황사', '미세먼지'],
#  ['거제도', '황사', '알려줄래'],
#  ['금오도', '황사', '궁금해요'],
#  ['자은도', '황사', '알려주세요'],
#  ['가거도', '황사', '미세먼지'],
#  ['청산도', '가려는데', '오늘', '황사', '궁금해요'],
#  ['보길도', '가는데', '미세먼지', '알려줘'],
#  ['거문도', '가려는데', '오늘', '황사', '미세먼지'],
#  ['흑산도', '가려는데', '오늘', '미세먼지', '알려줘'],
#  ['백령도', '오늘', '황사', '알려줘'],
#  ['안면도', '황사', '오늘', '미세먼지'],
#  ['강화도', '가려는데', '오늘', '미세먼지', '궁금해요'],
#  ['대부도', '가려는데', '오늘', '황사', '미세먼지'],
#  ['ㅋㅋ', '독도', '가려는데', '황사', '알려줄래'],
#  ['울릉도', '가는데', '황사', '알려줘'],
#  ['부평구', '가려는데', '미세먼지', '알려줘'],
#  ['그럼', '방배동', '오늘', '황사', '알려줘'],
#  ['상암동', '황사', '알려줄래'],
#  ['논현동', '황사좀', '알려줘'],
#  ['삼성동', '오늘', '미세먼지', '알려줘'],
#  ['개봉동', '가는데', '황사', '미세먼지'],
#  ['신수동', '가는데', '미세먼지', '알려줘'],
#  ['잠실', '가려는데', '근처', '황사', '알려줘'],
#  ['가락동', '가는데', '황사', '알려줘'],
#  ['부산', '종로', '오늘', '미세먼지', '알려줘'],
#  ['월계동', '미세먼지', '궁금해요'],
#  ['여의도', '가는데', '오늘', '미세먼지', '어때요'],
#  ['문정동', '가는데', '황사', '어떤가요'],
#  ['대포동', '가려는데', '오늘', '황사', '미세먼지'],
#  ['경주', '가는데', '오늘', '미세먼지', '어때'],
#  ['그럼', '먼지', '알려주겠니'],
#  ['먼지', '정보', '알려주세요', 'ㅋㅋ'],
#  ['그', '때', '미세먼지', '어떨까', 'ㅎㅎ'],
#  ['아', '그', '때', '먼지', '좋으려나'],
#  ['어후', '미세먼지', '어떨', '것', '같은데'],
#  ['아니', '미세먼지', '어떨까', 'ㅋㅋ'],
#  ['야', '미세먼지', '말해줄래'],
#  ['혹시', '미세먼지', '어떠니'],
#  ['그럼', '나', '미세먼지', '알려줘'],
#  ['아니', '지금', '먼지', '어떠냐'],
#  ['야', '미세먼지', '어때', '알려줘봐'],
#  ['그럼', '토요일', '먼지', '알려줘'],
#  ['아니', '야', '잠깐', '미세먼지', '어떠려나'],
#  ['그러면', '전주', '미세먼지', '어떤지', '말해줘'],
#  ['글면', '미세먼지', '궁금해서', '물어봤어'],
#  ['그럼', '이제', '먼지', '알려주세요'],
#  ['아니', '지금', '미세먼지', '어떠려나'],
#  ['그러면', '현재', '미세먼지', '어떠려나'],
#  ['그럼', '이제', '토요일', '먼지', '알려주겠니'],
#  ['ㅋㅋㅋ', '먼지', '궁금해'],
#  ['지금', 'ㅋㅋ', '먼지', '어떤데'],
#  ['ㅋㅋㅋㅋ', '저기', '지금', '미세먼지', '어떠냐'],
#  ['먼지', '완전', '문젠데', 'ㅋㅋ'],
#  ['ㅎㅎ', '세종', '먼지', '한', '번', '알려줘'],
#  ['그러면', '나', '이제', '모레', '미세먼지', '어떨까', '궁금해'],
#  ['미세먼지', '심할까', '궁금하네요', '이제'],
#  ['구로구', '근처', '미세먼지', '심할까'],
#  ['부산시', '종루구', '미세먼지', '알려줄래'],
#  ['그러면', '부산시', '용산구', '미세먼지', '알려줘'],
#  ['부산', '여행', '갈건데', '미세먼지', '어떠냐고'],
#  ['나', '전주', '여행', '간다', '미세먼지', '알려줘라'],
#  ['수요일', '나', '부산', '여행', '가는데', '미세먼지', '심할까', '궁금하네'],
#  ['아', 'ㅋㅋㅋ', '부산', '미세먼지', '알려줘'],
#  ['그러면', '마포구', '지금', '미세먼지', '심할까', '심해지냐'],
#  ['은평구', '현재', '미세먼지', '어떨까'],
#  ['아', '맞다', '미세먼지', '심할까', '좀', '알려줄래'],
#  ['관악구', '미세먼지', '먼지'],
#  ['미세먼지', '알려주겠니'],
#  ['미세먼지', '정보', '알려주세요'],
#  ['그', '때', '미세먼지', '심할까'],
#  ['그', '때', '미세먼지', '좋으려나'],
#  ['미세먼지', '어떨', '것', '같은데'],
#  ['미세먼지', '어때'],
#  ['미세먼지', '말해줄래'],
#  ['미세먼지', '어떠니'],
#  ['먼지', '많이', '꼈나'],
#  ['미세먼지', '어떠냐'],
#  ['야', '미세먼지', '어때'],
#  ['그럼', '과천', '미세먼지', '심할까'],
#  ['그럼', '증평', '미세먼지', '심할까'],
#  ['그럼', '양구', '미세먼지', '어때'],
#  ['그럼', '상주', '마스크', '써야', '할까'],
#  ['그럼', '계룡', '미세먼지', '어때'],
#  ['그럼', '거제', '미세먼지', '심할까'],
#  ['그럼', '제주', '미세먼지'],
#  ['그럼', '영월', '미세먼지'],
#  ['그럼', '구례', '미세먼지', '맑니'],
#  ['그럼', '나주', '마스크', '챙겨야해'],
#  ['그럼', '동두천', '미세먼지'],
#  ['그럼', '진도', '미세먼지', '심할까'],
#  ['그럼', '양주', '미세먼지'],
#  ['그럼', '상주', '미세먼지'],
#  ['그럼', '오산', '미세먼지', '심할까'],
#  ['그럼', '남원', '미세먼지', '심할까'],
#  ['그럼', '거제', '마스크', '필요하니'],
#  ['그럼', '철원', '미세먼지'],
#  ['동작구', '초미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['서대문구', '초미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['종로구', '초미세먼지', '심할지', '알아봐줘'],
#  ['노원구', '미세먼지', '심할지', '알아봐줘'],
#  ['강북구', '미세먼지', '어떤지', '알려주라'],
#  ['도봉구', '미세먼지', '어떤지', '말해', '줘봐'],
#  ['용산구', '초미세먼지', '심할지', '알려줘'],
#  ['강남구', '미세먼지', '알려주세요'],
#  ['광진구', '미세먼지', '심할지', '말해', '줘'],
#  ['은평구', '미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['강서구', '미세먼지', '말해', '주라'],
#  ['서대문구', '초미세먼지', '어떤지', '말해', '줘'],
#  ['동대문구', '초미세먼지', '심할지', '말해', '주세요'],
#  ['중랑구', '미세먼지', '심할지', '부탁', '해'],
#  ['영등포구', '초미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['금천구', '미세먼지', '심할지', '알려줄래'],
#  ['강서구', '미세먼지', '말해', '줘봐'],
#  ['강북구', '초미세먼지', '심할지', '말해', '줘'],
#  ['금천구', '미세먼지', '어떤지', '말해', '줘봐'],
#  ['서초구', '미세먼지', '말해', '주세요'],
#  ['강남구', '초미세먼지', '심할지', '알려주세요'],
#  ['강동구', '미세먼지', '말해', '줘'],
#  ['강북구', '초미세먼지', '어떤지', '말해', '주세요'],
#  ['용산구', '초미세먼지', '심할지', '말해', '줘'],
#  ['성동구', '초미세먼지', '심할지', '말해', '줄', '수', '있니'],
#  ['강남구', '미세먼지', '어떤지', '말해', '줘'],
#  ['종로구', '미세먼지', '어떤지', '알려주라'],
#  ['송파구', '초미세먼지', '어떤지', '알려줘'],
#  ['양천구', '초미세먼지', '어떤지', '알아봐줘'],
#  ['서대문구', '미세먼지', '어떤지', '말해', '주세요'],
#  ['동대문구', '미세먼지', '어떤지', '부탁', '합니다'],
#  ['영등포구', '초미세먼지', '어떤지', '말해', '줄', '수', '있니'],
#  ['노원구', '미세먼지', '심할지', '알려줄래'],
#  ['마포구', '초미세먼지', '어떤지', '알려줘'],
#  ['마포구', '미세먼지', '부탁', '해'],
#  ['은평구', '초미세먼지', '어떤지', '말해', '주세요'],
#  ['도봉구', '미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['서대문구', '미세먼지', '심할지', '알려줘'],
#  ['송파구', '초미세먼지', '심할지', '부탁', '해'],
#  ['강서구', '초미세먼지', '심할지', '말해', '줘봐'],
#  ['마포구', '미세먼지', '심할지', '알려주라'],
#  ['종로구', '미세먼지', '어떤지', '말해', '줘봐'],
#  ['마포구', '미세먼지', '심할지', '알', '수', '있을까'],
#  ['마포구', '초미세먼지', '심할지', '말해', '주라'],
#  ['송파구', '초미세먼지', '심할지', '말해', '주세요'],
#  ['마포구', '미세먼지', '알려줄래'],
#  ['용산구', '초미세먼지', '심할지', '알려줄', '수', '있니'],
#  ['서초구', '초미세먼지', '어떤지', '부탁', '해'],
#  ['은평구', '초미세먼지', '어떤지', '말해', '줘'],
#  ['종로구', '초미세먼지', '심할지', '알려줘'],
#  ['마포구', '미세먼지', '심할지', '말해', '주세요'],
#  ['송파구', '미세먼지', '어떤지', '말해', '주세요'],
#  ['노원구', '초미세먼지', '심할지', '알려줄래'],
#  ['중랑구', '미세먼지', '알려줄래'],
#  ['성동구', '초미세먼지', '어떤지', '알려줄래'],
#  ['강남구', '초미세먼지', '어떤지', '알려줄래'],
#  ['용산구', '미세먼지', '부탁', '합니다'],
#  ['서대문구', '미세먼지', '알고싶어'],
#  ['동대문구', '초미세먼지', '어떤지', '알려주세요'],
#  ['강남구', '초미세먼지', '어떤지', '말해', '줘'],
#  ['중구', '미세먼지', '어떤지', '부탁', '합니다'],
#  ['도봉구', '미세먼지', '말해', '주라'],
#  ['마포구', '초미세먼지', '어떤지', '알려주라'],
#  ['부산', '중랑구', '미세먼지'],
#  ['부산', '동작구', '마스크', '필요할까'],
#  ['부산', '강북구', '미세먼지', '심할까'],
#  ['부산', '구로구', '마스크', '챙겨야해'],
#  ['부산', '도봉구', '미세먼지'],
#  ['부산', '동대문구', '미세먼지', '심할까'],
#  ['부산', '양천구', '미세먼지'],
#  ['부산', '중랑구', '마스크', '필요해'],
#  ['부산', '도봉구', '미세먼지', '어떠냐'],
#  ['부산', '양천구', '미세먼지', '어떠니'],
#  ['부산', '금천구', '미세먼지'],
#  ['부산', '강서구', '미세먼지'],
#  ['부산', '중구', '마스크', '써야하니'],
#  ['부산', '강서구', '미세먼지', '어떠냐'],
#  ['부산', '서대문구', '미세먼지', '어떠니'],
#  ['부산', '종로구', '미세먼지', '어때'],
#  ['부산', '서초구', '미세먼지', '어때'],
#  ['부산', '동작구', '미세먼지', '심할까'],
#  ['부산', '관악구', '미세먼지', '심할까'],
#  ['부산', '중랑구', '미세먼지', '심할까'],
#  ['부산', '송파구', '미세먼지', '맑니'],
#  ['부산', '강남구', '공기상태'],
#  ['부산', '종로구', '미세먼지', '심할까'],
#  ['부산', '노원구', '미세먼지', '심할까'],
#  ['부산', '서초구', '미세먼지'],
#  ['부산', '동작구', '마스크', '챙길까'],
#  ['부산', '송파구', '초미세먼지', '어떨까'],
#  ['부산', '양천구', '초미세먼지', '심하냐고'],
#  ['부산', '노원구', '마스크', '써야하니'],
#  ['부산', '서초구', '마스크', '챙겨야', '할까'],
#  ['부산', '금천구', '초미세먼지', '심하냐고'],
#  ['부산', '강서구', '미세먼지', '심할까'],
#  ['부산', '마포구', '미세먼지', '어때'],
#  ['부산', '도봉구', '마스크', '챙겨야', '할까'],
#  ['부산', '구로구', '미세먼지', '어떨까'],
#  ['부산', '노원구', '초미세먼지', '어때'],
#  ['부산', '중구', '마스크', '챙길까'],
#  ['대구', '은평구', '미세먼지'],
#  ['대구', '노원구', '미세먼지', '맑니'],
#  ['대구', '금천구', '마스크', '필요하냐'],
#  ['대구', '용산구', '미세먼지', '심할까'],
#  ['대구', '중구', '미세먼지'],
#  ['대구', '강북구', '미세먼지'],
#  ['대구', '영등포구', '미세먼지'],
#  ['대구', '서대문구', '미세먼지', '심할까'],
#  ['대구', '강동구', '마스크', '필요하니'],
#  ['대구', '중랑구', '미세먼지'],
#  ['대구', '종로구', '마스크', '써야하니'],
#  ['대구', '노원구', '미세먼지'],
#  ['대구', '동대문구', '미세먼지'],
#  ['대구', '은평구', '미세먼지', '어때'],
#  ['대구', '강북구', '미세먼지', '심할까'],
#  ['대구', '강서구', '미세먼지'],
#  ['대구', '도봉구', '마스크', '필요해'],
#  ['대구', '강북구', '미세먼지', '어떠냐'],
#  ['대구', '송파구', '마스크', '가져가야하니'],
#  ['대구', '용산구', '미세먼지'],
#  ['대구', '광진구', '미세먼지', '어떠니'],
#  ['대구', '송파구', '초미세먼지', '어때'],
#  ['대구', '강서구', '초미세먼지', '심하냐고'],
#  ['대구', '성동구', '미세먼지'],
#  ['대구', '금천구', '마스크', '챙겨야해'],
#  ['대구', '영등포구', '미세먼지', '어떠니'],
#  ['대구', '강북구', '마스크', '써야', '할까'],
#  ['대구', '용산구', '미세먼지', '심할까'],
#  ['대구', '강남구', '미세먼지', '심할까'],
#  ['대구', '용산구', '미세먼지'],
#  ['대구', '성동구', '마스크', '가져가야하니'],
#  ['대구', '중랑구', '미세먼지'],
#  ['대구', '강북구', '미세먼지', '심할까'],
#  ['대구', '도봉구', '초미세먼지', '어떨까'],
#  ['대구', '동대문구', '미세먼지'],
#  ['대구', '관악구', '마스크', '써야하니'],
#  ['대구', '관악구', '미세먼지'],
#  ['대구', '노원구', '미세먼지', '어떨까'],
#  ['대구', '종로구', '공기상태'],
#  ['대구', '강서구', '초미세먼지', '어떨까'],
#  ['대구', '강남구', '미세먼지'],
#  ['인천', '강동구', '미세먼지'],
#  ['인천', '서대문구', '마스크', '써야하니'],
#  ['인천', '동작구', '마스크', '필요하냐'],
#  ['인천', '중랑구', '미세먼지', '공기'],
#  ['인천', '양천구', '미세먼지'],
#  ['인천', '노원구', '미세먼지', '어때'],
#  ['인천', '송파구', '미세먼지', '심할까'],
#  ['인천', '강남구', '미세먼지', '어떠냐'],
#  ['인천', '중구', '미세먼지', '공기상태'],
#  ['인천', '구로구', '미세먼지', '어떠니'],
#  ['인천', '도봉구', '미세먼지', '어떠니'],
#  ['인천', '강북구', '미세먼지'],
#  ['인천', '동작구', '마스크', '필요하니'],
#  ['인천', '관악구', '마스크', '챙겨야해'],
#  ['인천', '성동구', '미세먼지'],
#  ['인천', '노원구', '마스크', '필요하니'],
#  ['인천', '성동구', '미세먼지', '심할까'],
#  ['인천', '중랑구', '미세먼지', '심할까'],
#  ['인천', '광진구', '미세먼지'],
#  ['인천', '구로구', '마스크', '써야하니'],
#  ['인천', '성북구', '마스크', '필요해'],
#  ['인천', '동작구', '마스크', '쓸까'],
#  ['인천', '성동구', '초미세먼지', '어떨까'],
#  ['광주', '광진구', '미세먼지', '어때'],
#  ['광주', '강동구', '미세먼지'],
#  ['광주', '종로구', '미세먼지'],
#  ['광주', '강서구', '미세먼지'],
#  ['광주', '강남구', '미세먼지', '공기상태'],
#  ['광주', '영등포구', '미세먼지'],
#  ['광주', '동대문구', '미세먼지', '공기'],
#  ['광주', '광진구', '미세먼지'],
#  ['광주', '동대문구', '공기상태'],
#  ['광주', '금천구', '마스크', '가져갈까'],
#  ['광주', '광진구', '미세먼지'],
#  ['광주', '서대문구', '미세먼지'],
#  ['광주', '양천구', '마스크', '챙길까'],
#  ['광주', '강서구', '미세먼지'],
#  ['광주', '광진구', '미세먼지'],
#  ['광주', '구로구', '미세먼지', '심할까'],
#  ['광주', '양천구', '초미세먼지', '어때'],
#  ['광주', '영등포구', '미세먼지'],
#  ['광주', '강서구', '미세먼지', '심할까'],
#  ['광주', '서대문구', '마스크', '필요해'],
#  ['광주', '성동구', '미세먼지'],
#  ['광주', '마포구', '마스크', '챙겨야', '할까'],
#  ['광주', '강서구', '미세먼지'],
#  ['광주', '강북구', '초미세먼지', '심하냐고'],
#  ['울산', '용산구', '미세먼지'],
#  ['울산', '금천구', '미세먼지', '어떠냐'],
#  ['울산', '동대문구', '미세먼지'],
#  ['울산', '중랑구', '미세먼지', '어떠냐'],
#  ['울산', '영등포구', '마스크', '챙겨야', '할까'],
#  ['울산', '강남구', '미세먼지', '맑니'],
#  ['울산', '종로구', '마스크', '써야', '할까'],
#  ['울산', '동작구', '미세먼지', '어떠니'],
#  ['울산', '중랑구', '마스크', '가져갈까'],
#  ['울산', '강서구', '미세먼지', '어때'],
#  ['울산', '용산구', '미세먼지'],
#  ['울산', '송파구', '미세먼지', '어떠냐'],
#  ['울산', '양천구', '마스크', '챙겨야해'],
#  ['울산', '동작구', '미세먼지', '심할까'],
#  ['울산', '동대문구', '미세먼지', '심할까'],
#  ['울산', '노원구', '미세먼지'],
#  ['울산', '마포구', '미세먼지', '어떠냐'],
#  ['울산', '성동구', '초미세먼지', '어때'],
#  ['울산', '용산구', '마스크', '써야', '할까'],
#  ['울산', '동대문구', '미세먼지'],
#  ['전주', '금천구', '미세먼지', '공기'],
#  ['전주', '종로구', '미세먼지', '심할까'],
#  ['전주', '동작구', '미세먼지'],
#  ['전주', '양천구', '미세먼지'],
#  ['전주', '성북구', '미세먼지'],
#  ['전주', '중랑구', '미세먼지'],
#  ['전주', '도봉구', '미세먼지', '어때'],
#  ['전주', '도봉구', '마스크', '챙겨야해'],
#  ['전주', '강서구', '미세먼지', '심할까'],
#  ['전주', '영등포구', '미세먼지'],
#  ['전주', '구로구', '미세먼지', '심할까'],
#  ['광주', '금천구', '마스크', '필요할까'],
#  ['광주', '양천구', '마스크', '쓸까'],
#  ['광주', '마포구', '마스크', '필요하니'],
#  ['광주', '서대문구', '마스크', '챙겨야', '할까'],
#  ['광주', '강남구', '미세먼지', '심할까'],
#  ['광주', '중랑구', '마스크', '필요할까'],
#  ['광주', '도봉구', '마스크', '챙길까'],
#  ['광주', '노원구', '미세먼지'],
#  ['광주', '중랑구', '미세먼지'],
#  ['광주', '금천구', '미세먼지', '심할까'],
#  ['광주', '강북구', '공기상태'],
#  ['광주', '금천구', '미세먼지', '어때'],
#  ['광주', '강동구', '마스크', '필요해'],
#  ['광주', '강동구', '미세먼지', '심할까'],
#  ['광주', '송파구', '미세먼지'],
#  ['광주', '마포구', '마스크', '가져갈까'],
#  ['광주', '종로구', '미세먼지'],
#  ['광주', '영등포구', '미세먼지', '심할까'],
#  ['대전', '구로구', '미세먼지', '심할까'],
#  ['대전', '관악구', '미세먼지', '어때'],
#  ['대전', '종로구', '미세먼지', '공기'],
#  ['대전', '용산구', '마스크', '필요하냐'],
#  ['대전', '종로구', '미세먼지'],
#  ['대전', '중랑구', '마스크', '필요하냐'],
#  ['대전', '강남구', '미세먼지'],
#  ['대전', '노원구', '미세먼지'],
#  ['대전', '은평구', '미세먼지', '심할까'],
#  ['대전', '광진구', '미세먼지', '공기상태'],
#  ['대전', '영등포구', '미세먼지', '어떨까'],
#  ['대전', '성북구', '미세먼지', '심할까'],
#  ['대전', '양천구', '마스크', '써야하니'],
#  ['대전', '은평구', '미세먼지'],
#  ['대전', '성북구', '마스크', '챙길까'],
#  ['대전', '관악구', '미세먼지'],
#  ['대전', '강북구', '미세먼지'],
#  ['대전', '구로구', '마스크', '가져갈까'],
#  ['대전', '구로구', '미세먼지', '어떠니'],
#  ['대전', '동대문구', '마스크', '써야하니'],
#  ['대전', '중랑구', '미세먼지', '어떠니'],
#  ['대전', '서초구', '미세먼지'],
#  ['대전', '강북구', '마스크', '챙겨야', '할까'],
#  ['대전', '송파구', '미세먼지'],
#  ['대전', '서초구', '마스크', '가져가야하니'],
#  ['대전', '강동구', '마스크', '가져가야하니'],
#  ['대전', '동대문구', '미세먼지', '심할까'],
#  ['대전', '구로구', '마스크', '필요할까'],
#  ['서울', '강동구', '미세먼지', '심할까'],
#  ['서울', '영등포구', '마스크', '필요하니'],
#  ['서울', '서대문구', '미세먼지'],
#  ['서울', '중구', '미세먼지'],
#  ['서울', '금천구', '미세먼지', '공기상태'],
#  ['서울', '광진구', '초미세먼지', '심하냐고'],
#  ['서울', '성동구', '미세먼지'],
#  ['서울', '중랑구', '마스크', '챙겨야', '할까'],
#  ['서울', '양천구', '미세먼지', '공기'],
#  ['서울', '송파구', '마스크', '필요하니'],
#  ['서울', '서대문구', '미세먼지'],
#  ['서울', '도봉구', '미세먼지'],
#  ['서울', '노원구', '미세먼지'],
#  ['서울', '은평구', '마스크', '가져가야하니'],
#  ['서울', '강동구', '마스크', '필요할까'],
#  ['서울', '성동구', '미세먼지', '심할까'],
#  ['서울', '성동구', '미세먼지'],
#  ['서울', '성동구', '미세먼지', '어떠냐'],
#  ['서울', '서초구', '초미세먼지', '어때'],
#  ['서울', '양천구', '마스크', '가져가야하니'],
#  ['서울', '강남구', '미세먼지', '심할까'],
#  ['서울', '강동구', '마스크', '써야하니'],
#  ['서울', '종로구', '초미세먼지', '어떨까'],
#  ['서울', '은평구', '공기'],
#  ['서울', '송파구', '마스크', '필요하냐'],
#  ['서울', '송파구', '마스크', '쓸까'],
#  ['서울', '은평구', '미세먼지', '심할까'],
#  ['서울', '노원구', '마스크', '가져가야하니'],
#  ['서울', '중랑구', '미세먼지', '공기상태'],
#  ['서울', '강북구', '마스크', '필요할까'],
#  ['서울', '용산구', '미세먼지', '심할까'],
#  ['서울', '용산구', '미세먼지'],
#  ['서울', '서초구', '미세먼지'],
#  ['서울', '용산구', '마스크', '써야하니'],
#  ['서울', '서대문구', '미세먼지'],
#  ['서울', '구로구', '마스크', '챙겨야', '할까'],
#  ['서울', '구로구', '미세먼지', '어떠냐'],
#  ['서울', '금천구', '미세먼지'],
#  ['서울', '성북구', '미세먼지'],
#  ['서울', '동작구', '초미세먼지', '어떨까'],
#  ['서울', '서대문구', '마스크', '가져갈까'],
#  ['서울', '광진구', '마스크', '필요할까'],
#  ['서울', '중랑구', '미세먼지'],
#  ['서울', '동대문구', '미세먼지'],
#  ['서울', '도봉구', '마스크', '가져가야하니'],
#  ['서울', '송파구', '마스크', '써야하니'],
#  ['서울', '관악구', '미세먼지'],
#  ['서울', '관악구', '마스크', '챙길까'],
#  ['서울', '은평구', '미세먼지'],
#  ['서울', '강서구', '마스크', '써야하니'],
#  ['서울', '광진구', '미세먼지'],
#  ['서울', '노원구', '미세먼지', '좋니'],
#  ['서울', '구로구', '미세먼지'],
#  ['서울', '종로구', '미세먼지', '어떠냐'],
#  ['서울', '중구', '초미세먼지', '어떨까'],
#  ['서울', '강북구', '마스크', '가져가야하니'],
#  ['서울', '강동구', '초미세먼지', '심하냐고'],
#  ['서울', '광진구', '미세먼지', '공기'],
#  ['서울', '구로구', '공기상태'],
#  ['서울', '영등포구', '마스크', '써야', '할까'],
#  ['서울', '중랑구', '미세먼지', '심할까'],
#  ['서울', '서대문구', '미세먼지'],
#  ['서울', '동작구', '미세먼지', '심할까'],
#  ['서울', '영등포구', '마스크', '필요하냐'],
#  ['서울', '동대문구', '초미세먼지', '어떨까'],
#  ['서울', '영등포구', '미세먼지', '심할까'],
#  ['서울', '중구', '미세먼지', '맑니'],
#  ['서울', '구로구', '미세먼지', '어때'],
#  ...]

# %% [markdown]
# # Embedding

# %%
class EpochLogger(CallbackAny2Vec):
    # 학습 중간 프린트를 하기 위한 logger
    def __init__(self):
        self.epoch = 0
        
    def on_epoch_begin(self, model):
        print("Epoch #{} start".format(self.epoch))

    def on_epoch_end(self, model):
        print("Epoch #{} end".format(self.epoch))
        self.epoch += 1

# https://radimrehurek.com/gensim/models/word2vec.html#gensim.models.word2vec.Word2Vec
# https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#online-training-resuming-training
class MakeEmbed:
    
    def __init__(self):
        self.model_dir = "./"
        self.vector_size = 300 # 임베딩 사이즈
        self.window_size = 3 # 몇개의 단어로 예측을 할것인지
        self.workers = 8 # 학습 스레드의 수
        self.min_count = 2 # 단어의 최소 빈도수
        self.iter = 1000 # 1epoch당 학습 수
        self.sg = 1 # 1: skip-gram, 0: CBOW
        self.model_file = "./data/pretraining/word2vec_skipgram_{}_{}_{}".format(self.vector_size, self.window_size, self.min_count)
        self.epoch_logger = EpochLogger()
        
    def word2vec_init(self): # word2vec 초기화 및 세팅
        self.word2vec = Word2Vec(size=self.vector_size,
                         window=self.window_size,
                         workers=self.workers,
                         min_count=self.min_count,
                         compute_loss=True,
                         iter=self.iter)
        
    def word2vec_build_vocab(self, dataset): # 단어장 만들기
        self.word2vec.build_vocab(dataset)
        
    def word2vec_most_similar(self, query): # 비슷한 단어 계산
        print(self.word2vec.most_similar(query))
        
    def word2vec_train(self,embed_dataset, epoch = 0): # 학습
        if(epoch == 0):
            epoch = self.word2vec.epochs + 1
        self.word2vec.train(
            sentences=embed_dataset,
            total_examples=self.word2vec.corpus_count,
            epochs=epoch,
            callbacks=[self.epoch_logger]
        )

        self.word2vec.save(self.model_file + '.gensim')
        self.vocab = self.word2vec.wv.index2word
        self.vocab = {word: i for i, word in enumerate(self.vocab)}

    def load_word2vec(self):

        if not os.path.exists(self.model_file+'.gensim'):
            raise Exception("모델 로딩 실패 "+ self.model_file+'.gensim')

  
        self.word2vec = Word2Vec.load(self.model_file+'.gensim')
        self.vocab = self.word2vec.wv.index2word
        self.vocab.insert(0,"<UNK>") # vocal에 없는 토큰이 등장할 경우를 대비한 <UNK>
        self.vocab.insert(0,"<PAD>") # 길이를 맞추기 위한 padding <PAD>
        self.vocab = {word: i for i, word in enumerate(self.vocab)}
        
    def query2idx(self, query):
        sent_idx = []

        for word in query:
            if(self.vocab.get(word)):
                idx = self.vocab[word]
            else:
                idx = 1

            sent_idx.append(idx)

        return sent_idx

# %%
embed = MakeEmbed()

embed.word2vec_init()

embed.word2vec.build_vocab(embed_dataset)

# %%
embed.word2vec.wv.most_similar('미세먼지')
# Out:
# [('충북', 0.15711839497089386),
#  ('모르겠네', 0.15671491622924805),
#  ('나온', 0.15524284541606903),
#  ('마포구', 0.15245869755744934),
#  ('예산', 0.15181970596313477),
#  ('8일', 0.1499040722846985),
#  ('그래도', 0.14325489103794098),
#  ('공연', 0.14307965338230133),
#  ('2O일', 0.14078018069267273),
#  ('줘줘', 0.13754616677761078)]

# %%
embed.word2vec_train(embed_dataset,10)
# Out:
# Epoch #0 start
# Epoch #0 end
# Epoch #1 start
# Epoch #1 end
# Epoch #2 start
# Epoch #2 end
# Epoch #3 start
# Epoch #3 end
# Epoch #4 start
# Epoch #4 end
# Epoch #5 start
# Epoch #5 end
# Epoch #6 start
# Epoch #6 end
# Epoch #7 start
# Epoch #7 end
# Epoch #8 start
# Epoch #8 end
# Epoch #9 start
# Epoch #9 end

# %%
embed.word2vec.wv.most_similar('미세먼지')
# Out:
# [('먼지', 0.8903840780258179),
#  ('날씨', 0.851744532585144),
#  ('내일모레', 0.8270372152328491),
#  ('모레', 0.8137878775596619),
#  ('그니까', 0.8093109130859375),
#  ('화요일', 0.8018124103546143),
#  ('오늘', 0.7840480804443359),
#  ('수요일', 0.7829867601394653),
#  ('충남', 0.7718997001647949),
#  ('하늘', 0.7706325054168701)]
