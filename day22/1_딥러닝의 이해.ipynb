# %% [markdown]
# # **1. Perceptron(Actificial Neural Network)**

# %% [markdown]
# ### **1-1. Neuron**

# %% [markdown]
# ![이미지](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Neuron_Hand-tuned.svg/400px-Neuron_Hand-tuned.svg.png)
#
# * 수상돌기 : 다른 뉴런들로부터 신호를 받아 특정 조건을 만족하면
# 축삭돌기로 보냄
# * 축살돌기 : 전달받음 신호를 다른 뉴런으로 전달

# %% [markdown]
# ![이미지](https://www.thedailypost.kr/news/photo/201904/70084_60318_3157.png
# )
# * 파블로프의 개 실험
# > 먹이를 봤을 때 반응하는 뉴런 -> 시냅스 -> 침샘분비 뉴런
# > 종을 쳤을 때 반응하는 뉴런 -> 시냅스 -> 침샘분비 뉴런
#
# ### **이것을 모방해서 만듣 인공신경망 -> Perceptron**

# %% [markdown]
# # ***목표 : 적절한 weight를 찾는게 Neral Network에서 핵심***

# %% [markdown]
# # **Deep Neural Network : layer 수가 최소 2개 이상인 network**

# %% [markdown]
# ## **1-2 Training Neural Networks**

# %% [markdown]
# Nerual Network이 얼마나 잘하는지 or 얼마나 못하는지에 대한 척도가 필요함
#
#
#
# *   Lostt Function / Cost Function

# %% [markdown]
# # loss 값을 줄이는 방법 : 미분(접선의 기울기) 이용

# %% [markdown]
# ## 1-3. 답러닝의 키포인트

# %% [markdown]
# * 데이터
# * 모델(CNN, RNN, 트랜스포머, 멀티레이어 퍼셉트론..)
# * loss function
# * 알고리즘 (Gradient Descent를 기초로 많은 알고리즘이 만들어짐)
